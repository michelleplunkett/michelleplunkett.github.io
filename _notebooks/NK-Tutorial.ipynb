# %% [markdown]
# # NK's Tutorial for NEA Arts Data
#
# To begin, install Miniconda2 through command line tools (on MacOS). I used the following steps:
#
# 1. Install homebrew through terminal.
# 2. Determine which python version you have by running: python --version
# 3. Run: brew install wget
# 4. Run: wget https://repo.continuum.io/miniconda/Miniconda2-latest-MacOSX-x86_64.sh
# 5. Run: bash Miniconda2-latest-MacOSX-x86_64.sh
#     * (Note: install the corresponding version of miniconda depending on your python version)
# 6. Complete the installer's steps.
# 7. Make sure the PATH to conda has been added to your .bash_profile by running: nano ~/.bash_profile
#     * (If it is not added, run sudo nano ~/.bash_profile and add ' export PATH="$HOME/miniconda2/bin:$PATH" '
#     to the file and save it.
# 8. Run: source ~/.bash_profile if you had to edit this file.
# 9. Install the r-irkernel package to run a local version of R.
#     * Instructions: https://irkernel.github.io/installation/
# 10. (Optional: Start a Jupyter Notebook): jupyter notebook
#
# You are now ready to begin the tutorial!

# %% [markdown]
# # Greer's Tutorial

# %% [markdown]
# ## Why R?
# 1. Free/open source geocode capabilties.
# 2. Merging/matching to congressional districts/MSAs/counties/etc.
# 3. Add geographic indicators to geocoded data.

# %% [markdown]
# ## Basic Information about R & RStudio

# %% [markdown]
# ### Screens in RStudio
# 1. **Script window:** *(top left)* the commands and functions that you would like to keep for later use
# 2. **Console:** *(bottom left)* the window where the commands run and produce outputs. Commands typed here do not get saved in your script.
# 3. **Environment/Help window:** shows details about the current dataset loaded and any help documentation for R
# 4. **Plots/packages window:** shows details about the current package selected (for example, details about the "neaR" package)

# %% [markdown]
# ### How to Run a Script
# 1. Highlight the command you would like to run
# 2. Click the key combination CTRL+ENTER

# %% [markdown]
# ## Step 1
#
# ### Step 1.a.
# Install the devtools package by writing the following command in the script window. Highlight the command in a script window and click CTRL+ENTER to run the command.
#
# The command is finished executing when the ">" arrow appears in the console.

# %%
install.packages("devtools")
# Out:
# The downloaded binary packages are in
# 	/var/folders/kp/2dzcn39934x4700rb9kpvtx00000gn/T//RtmpUbOjsi/downloaded_packages

# %% [markdown]
# ### Step 1.b.
# Enable the devtools package by writing the following command in the script window. Then, highlight "library(devtools)" and click CTRL+ENTER. If done correctly, the next line in the console should show this symbol ">".

# %%
library(devtools)
# Out:
# Warning message:
# “package ‘devtools’ was built under R version 3.4.1”

# %% [markdown]
# ## Step 2
#
# ### Step 2.a.
# Install Greer Mellon's "neaR" package.

# %%
install_github("gmellon/neaR")
# Out:
# Skipping install of 'neaR' from a github remote, the SHA1 (c969f1b9) has not changed since last install.
#   Use `force = TRUE` to force installation

# %% [markdown]
# ### Step 2.b.
#
# Enable the neaR package.

# %%
library(neaR)
# Out:
# Loading required package: sf
# Warning message:
# “package ‘sf’ was built under R version 3.4.1”Linking to GEOS 3.6.1, GDAL 2.1.3, proj.4 4.9.3
# Loading required package: stringr
# Loading required package: tigris
# As of version 0.5.1, tigris does not cache downloaded data by default. To enable caching of data, set `options(tigris_use_cache = TRUE)` in your R script or .Rprofile.
#
# Attaching package: ‘tigris’
#
# The following object is masked from ‘package:graphics’:
#
#     plot
#
# Loading required package: RJSONIO
# Loading required package: RDSTK
# Loading required package: plyr
# Loading required package: rjson
#
# Attaching package: ‘rjson’
#
# The following objects are masked from ‘package:RJSONIO’:
#
#     fromJSON, toJSON
#
# Loading required package: RCurl
# Loading required package: bitops
# Loading required package: progress
# Loading required package: sp
# Warning message:
# “package ‘sp’ was built under R version 3.4.1”Loading required package: httr

# %% [markdown]
# ## Step 3
#
# ### Step 3.a.
#
# Set your working directory. This is where your files will be located after the scripts run.
#
# In the RStudio application window, at the top select **Session --> Set working directory --> Choose Directory --> (select folder location you would like to work in)**

# %%
setwd("/Users/michelle/Desktop/Tableau Workshop Materials - 081617/Data Files/")

# %% [markdown]
# ### Step 3.b.
#
# Use the following command to receive a list of files and directories in the working directory previously set.

# %%
list.files()
# Out:
# [1] "cb_2015_06_tract_500k.zip"
# [2] "NEA_for_tableau.csv"
# [3] "NEA_workshop_file.csv"
# [4] "PEP_2016_GCTPEPANNR.US23PR_with_ann.csv"
# [5] "population_by_state.csv"

# %% [markdown]
# ## Step 4
# ### Step 4.a.
# Assign an object to a data file by typing in the following command to your script window and using the CTRL-ENTER key combination.

# %%
NEA <- read.csv("NEA_workshop_file.csv" , stringsAsFactors=F )

# %% [markdown]
# ### Step 4.b.
# Use the following command to view the CSV/dataset that you just assigned to the "NEA" object.

# %%
View(NEA)
# Out:
# Error in View(NEA): ‘View()’ not yet supported in the Jupyter R kernel
# Traceback:
#
# 1. View(NEA)
# 2. stop(sQuote("View()"), " not yet supported in the Jupyter R kernel")

# %% [markdown]
# You have now successfully loaded data into RStudio and can now use this data with the "neaR" package commands.

# %% [markdown]
# # Working with the neaR Package

# %%
NEA$CoZip
# Out:
#    [1] "20005-1747" "20005-1747" "20005-1747" "20005-1747" "20005-1747"
#    [6] "20005-1747" "20005-1747" "20005-1747" "20005-1747" "20005-1747"
#   [11] "20005-1747" "02115-4557" "02115-4557" "02115-4557" "02115-4557"
#   [16] "02115-4557" "02115-4557" "02115-4557" "02115-4557" "02115-4557"
#   [21] "02115-4557" "02115-4557" "02115-4557" "02115-4557" "02115-4557"
#   [26] "02115-4557" "02115-4557" "02115-4557" "02115-4557" "04011-8449"
#   [31] "84602-1400" "84602-1400" "84602-1400" "84602-1400" "91355-2340"
#   [36] "91355-2340" "91355-2340" "91355-2340" "91355-2340" "91355-2340"
#   [41] "91355-2340" "91355-2340" "91355-2340" "91355-2340" "91355-2340"
#   [46] "91355-2340" "91355-2340" "91355-2340" "91355-2340" "91355-2340"
#   [51] "91355-2340" "44106-1705" "14627-0140" "14627-0140" "14627-0140"
#   [56] "14627-0140" "14627-0140" "14627-0140" "14627-0140" "14627-0140"
#   [61] "14627-0140" "14627-0140" "14627-0140" "14627-0140" "14627-0140"
#   [66] "14627-0140" "14627-0140" "14627-0140" "14627-0140" "14627-0140"
#   [71] "14627-0140" "14627-0140" "90012-3034" "90012-3034" "90012-3034"
#   [76] "90012-3034" "90012-3034" "90012-3034" "90012-3034" "90012-3034"
#   [81] "90012-3034" "90012-3034" "90012-3034" "90012-3034" "90012-3034"
#   [86] "90012-3034" "10027-4689" "10027-4689" "10027-4689" "10027-4689"
#   [91] "10027-4689" "10027-4689" "10027-4689" "10027-4689" "10027-4689"
#   [96] "48109-1274" "48109-1274" "48109-1274" "48109-1274" "48109-1274"
#  [101] "48109-1274" "48109-1274" "48109-1274" "48109-1274" "48109-1274"
#  [106] "48109-1274" "48109-1274" "48109-1274" "48109-1274" "48109-1274"
#  [111] "48109-1274" "48109-1274" "48109-1274" "48109-1274" "93108-2865"
#  [116] "93108-2865" "93108-2865" "93108-2865" "93108-2865" "93108-2865"
#  [121] "93108-2865" "93108-2865" "20566-0001" "20566-0001" "20566-0001"
#  [126] "20566-0001" "20566-0001" "20566-0001" "20566-0001" "20566-0001"
#  [131] "44074-1099" "60604-2559" "60604-2559" "60604-2559" "60604-2559"
#  [136] "60604-2559" "60604-2559" "60604-2559" "60604-2559" "60604-2559"
#  [141] "60604-2559" "60604-2559" "60604-2559" "60604-2559" "60604-2559"
#  [146] "60604-2559" "60604-2559" "60604-2559" "60604-2559" "60604-2559"
#  [151] "60604-2559" "60604-2559" "60604-2559" "60604-2559" "60604-2559"
#  [156] "53201-0340" "53201-0340" "53201-0340" "53201-0340" "53201-0340"
#  [161] "53201-0340" "53201-0340" "53201-0340" "53201-0340" "06520-8327"
#  [166] "06520-8327" "06520-8327" "06520-8327" "06520-8327" "06520-8327"
#  [171] "06520-8327" "06520-8327" "06520-8327" "06520-8327" "06520-8327"
#  [176] "06520-8327" "06520-8327" "06520-8327" "06520-8327" "06520-8327"
#  [181] "06520-8327" "05346-0507" "05346-0507" "05346-0507" "05346-0507"
#  [186] "05346-0507" "05346-0507" "05346-0507" "10004-2277" "10004-2277"
#  [191] "10004-2277" "10004-2277" "10004-2277" "10004-2277" "10004-2277"
#  [196] "10004-2277" "10004-2277" "10022-1001" "10022-1001" "10022-1001"
#  [201] "10022-1001" "10022-1001" "10022-1001" "10022-1001" "10022-1001"
#  [206] "85287-6011" "85287-6011" "85287-6011" "85287-6011" "85287-6011"
#  [211] "85287-6011" "85287-6011" "85287-6011" "85287-6011" "85287-6011"
#  [216] "85287-6011" "85287-6011" "85287-6011" "85287-6011" "85287-6011"
#  [221] "85287-6011" "85287-6011" "85287-6011" "85287-6011" "85287-6011"
#  [226] "85287-6011" "85287-6011" "85287-6011" "85287-6011" "85287-6011"
#  [231] "85287-6011" "85287-6011" "85287-6011" "85287-6011" "85287-6011"
#  [236] "85287-6011" "85287-6011" "85287-6011" "85287-6011" "85287-6011"
#  [241] "85287-6011" "85287-6011" "85287-6011" "85287-6011" "85287-6011"
#  [246] "85287-6011" "85287-6011" "85287-6011" "85287-6011" "85287-6011"
#  [251] "85287-6011" "85287-6011" "93106-2050" "93106-2050" "93106-2050"
#  [256] "93106-2050" "93106-2050" "93106-2050" "93106-2050" "93106-2050"
#  [261] "93106-2050" "93106-2050" "93106-2050" "93106-2050" "93106-2050"
#  [266] "93106-2050" "93106-2050" "93106-2050" "93106-2050" "93106-2050"
#  [271] "93106-2050" "10012-3396" "10012-3396" "10012-3396" "10012-3396"
#  [276] "10012-3396" "10012-3396" "10012-3396" "10012-3396" "10012-3396"
#  [281] "10012-3396" "10012-3396" "10012-3396" "10012-3396" "10012-3396"
#  [286] "10012-3396" "61820-7406" "61820-7406" "61820-7406" "61820-7406"
#  [291] "61820-7406" "61820-7406" "61820-7406" "61820-7406" "61820-7406"
#  [296] "61820-7406" "61820-7406" "61820-7406" "61820-7406" "61820-7406"
#  [301] "94613-1301" "94613-1301" "94613-1301" "94613-1301" "94613-1301"
#  [306] "94613-1301" "94613-1301" "94613-1301" "94613-1301" "94613-1301"
#  [311] "94613-1301" "55102-1439" "55102-1439" "55102-1439" "55102-1439"
#  [316] "55102-1439" "55102-1439" "55102-1439" "55102-1439" "55102-1439"
#  [321] "55102-1439" "55102-1439" "80639-0001" "80639-0001" "80639-0001"
#  [326] "80639-0001" "80639-0001" "80639-0001" "80639-0001" "08543-0036"
#  [331] "08543-0036" "08543-0036" "08543-0036" "08543-0036" "12180-3522"
#  [336] "12180-3522" "12180-3522" "12180-3522" "12180-3522" "12180-3522"
#  [341] "12180-3522" "12180-3522" "12180-3522" "12201-0009" "12201-0009"
#  [346] "12201-0009" "12201-0009" "12201-0009" "12201-0009" "12201-0009"
#  [351] "12201-0009" "12201-0009" "12201-0009" "12201-0009" "12201-0009"
#  [356] "12201-0009" "12201-0009" "12201-0009" "12201-0009" "12201-0009"
#  [361] "12201-0009" "12201-0009" "12201-0009" "12201-0009" "12201-0009"
#  [366] "12201-0009" "12201-0009" "12201-0009" "12201-0009" "12201-0009"
#  [371] "12201-0009" "12201-0009" "12201-0009" "94304-8445" "94304-8445"
#  [376] "94304-8445" "94304-8445" "94304-8445" "94304-8445" "94304-8445"
#  [381] "94304-8445" "94304-8445" "06106-1222" "06106-1222" "06106-1222"
#  [386] "06106-1222" "06106-1222" "06106-1222" "06106-1222" "06106-1222"
#  [391] "06106-1222" "06106-1222" "06106-1222" "10128-1612" "10128-1612"
#  [396] "10128-1612" "10128-1612" "10128-1612" "10128-1612" "10128-1612"
#  [401] "10128-1612" "10128-1612" "10128-1612" "10128-1612" "06813-3167"
#  [406] "06813-3167" "12601-3214" "12601-3214" "12601-3214" "12601-3214"
#  [411] "12601-3214" "12601-3214" "12601-3214" "11201-1303" "10463-3039"
#  [416] "10463-3039" "10463-3039" "10463-3039" "11217-1486" "11217-1486"
#  [421] "11217-1486" "11217-1486" "11217-1486" "11217-1486" "11217-1486"
#  [426] "11217-1486" "11217-1486" "90095-1406" "90095-1406" "90095-1406"
#  [431] "90095-1406" "90095-1406" "90095-1406" "90095-1406" "90095-1406"
#  [436] "90095-1406" "90095-1406" "90095-1406" "90095-1406" "90095-1406"
#  [441] "90095-1406" "90095-1406" "90095-1406" "90095-1406" "90095-1406"
#  [446] "90095-1406" "90095-1406" "90095-1406" "90095-1406" "90095-1406"
#  [451] "90095-1406" "90095-1406" "90095-1406" "90095-1406" "90095-1406"
#  [456] "90095-1406" "90095-1406" "90095-1406" "90095-1406" "90095-1406"
#  [461] "90095-1406" "90095-1406" "90095-1406" "94704-5940" "94704-5940"
#  [466] "94704-5940" "94704-5940" "94704-5940" "94704-5940" "94704-5940"
#  [471] "94704-5940" "94704-5940" "94704-5940" "94704-5940" "94704-5940"
#  [476] "94704-5940" "94704-5940" "94704-5940" "94704-5940" "94704-5940"
#  [481] "94704-5940" "94704-5940" "94704-5940" "94704-5940" "94704-5940"
#  [486] "94704-5940" "94704-5940" "94704-5940" "94704-5940" "94704-5940"
#  [491] "94704-5940" "94704-5940" "94704-5940" "94704-5940" "10001-3813"
#  [496] "10001-3813" "10001-3813" "10001-3813" "10001-3813" "10001-3813"
#  [501] "10001-3813" "10001-3813" "10001-3813" "10001-3813" "10001-3813"
#  [506] "10001-3813" "10001-3813" "97239-3817" "97239-3817" "97239-3817"
#  [511] "97239-3817" "10019-0026" "10019-0026" "10019-0026" "10019-0026"
#  [516] "10019-0026" "10019-0026" "10019-0026" "10019-0026" "27858-5235"
#  [521] "27858-5235" "27858-5235" "27858-5235" "27858-5235" "96822-2234"
#  [526] "96822-2234" "96822-2234" "96822-2234" "96822-2234" "96822-2234"
#  [531] "96822-2234" "96822-2234" "96822-2234" "96822-2234" "96822-2234"
#  [536] "96822-2234" "96822-2234" "22207-3606" "77005-1892" "77005-1892"
#  [541] "52242-1320" "52242-1320" "52242-1320" "52242-1320" "52242-1320"
#  [546] "52242-1320" "52242-1320" "52242-1320" "52242-1320" "52242-1320"
#  [551] "52242-1320" "52242-1320" "52242-1320" "52242-1320" "52242-1320"
#  [556] "52242-1320" "52242-1320" "52242-1320" "52242-1320" "52242-1320"
#  [561] "94122-2307" "94122-2307" "94122-2307" "94122-2307" "94122-2307"
#  [566] "94122-2307" "94122-2307" "94122-2307" "10027-5706" "10027-5706"
#  [571] "10027-5706" "10027-5706" "10027-5706" "10027-5706" "10027-5706"
#  [576] "15213-3504" "15213-3504" "15213-3504" "15213-3504" "15213-3504"
#  [581] "15213-3504" "87504-2227" "87504-2227" "87504-2227" "87504-2227"
#  [586] "87504-2227" "87504-2227" "87504-2227" "87504-2227" "87504-2227"
#  [591] "87504-2227" "87504-2227" "87504-2227" "10018-4016" "10018-4016"
#  [596] "10018-4016" "10018-4016" "10018-4016" "10018-4016" "10018-4016"
#  [601] "10018-4016" "10018-4016" "10018-4016" "10018-4016" "10018-4016"
#  [606] "10018-4016" "19103-7080" "19103-7080" "19103-7080" "19103-7080"
#  [611] "19103-7080" "10025-1284" "10025-1284" "10025-1284" "10025-1284"
#  [616] "10025-6990" "10025-6990" "10025-6990" "10025-6990" "10025-6990"
#  [621] "10025-6990" "10025-6990" "10025-6990" "10025-6990" "10025-6990"
#  [626] "10025-6990" "76102-3177" "76102-3177" "76102-3177" "76102-3177"
#  [631] "76102-3177" "76102-3177" "76102-3177" "76102-3177" "76102-3177"
#  [636] "76102-3177" "76102-3177" "10013-1268" "10013-1268" "10013-1268"
#  [641] "10013-1268" "10013-1268" "10013-1268" "10013-1268" "10013-1268"
#  [646] "10013-1268" "10013-1268" "10013-1268" "10013-1268" "10013-1268"
#  [651] "55403-1139" "55403-1139" "55403-1139" "55403-1139" "55403-1139"
#  [656] "55403-1139" "55403-1139" "10471-2899" "10471-2899" "10471-2899"
#  [661] "10471-2899" "10471-2899" "10471-2899" "10471-2899" "63103-1024"
#  [666] "21217-4103" "21217-4103" "21217-4103" "21217-4103" "21217-4103"
#  [671] "21217-4103" "02116-2639" "02116-2639" "02116-2639" "20015-2024"
#  [676] "20015-2024" "20015-2024" "20015-2024" "20015-2024" "20015-2024"
#  [681] "20015-2024" "20015-2024" "45202-7531" "45202-7531" "45202-7531"
#  [686] "10022-2049" "10022-2049" "10022-2049" "10022-2049" "43215-4203"
#  [691] "43215-4203" "43215-4203" "43215-4203" "43215-4203" "43215-4203"
#  [696] "43215-4203" "43215-4203" "94110-2586" "94110-2586" "94110-2586"
#  [701] "94110-2586" "94110-2586" "94110-2586" "94110-2586" "94110-2586"
#  [706] "10701-5108" "10701-5108" "10701-5108" "02116-6439" "02116-6439"
#  [711] "02116-6439" "02116-6439" "02116-6439" "02116-6439" "02116-6439"
#  [716] "02116-6439" "02116-6439" "90012-3013" "90012-3013" "90012-3013"
#  [721] "90012-3013" "90012-3013" "90012-3013" "90012-3013" "90012-3013"
#  [726] "79711-0658" "53202-3148" "53202-3148" "53202-3148" "53202-3148"
#  [731] "53202-3148" "53202-3148" "60602-1912" "44106-1796" "44106-1796"
#  [736] "44106-1796" "44106-1796" "44106-1796" "44106-1796" "44106-1796"
#  [741] "44106-1796" "44106-1796" "03060-3425" "03060-3425" "20083829"
#  [746] "20083829"   "20083829"   "20083829"   "20083829"   "20083829"
#  [751] "20083829"   "20083829"   "19107-4117" "19107-4117" "55403-3746"
#  [756] "55403-3746" "55403-3746" "55403-3746" "55403-3746" "55403-3746"
#  [761] "55403-3746" "55403-3746" "55403-3746" "55403-3746" "94102-5972"
#  [766] "94102-5972" "94102-5972" "94102-5972" "94102-5972" "94102-5972"
#  [771] "94102-5972" "94102-5972" "94102-5972" "94102-4507" "94102-4507"
#  [776] "94102-4507" "94102-4507" "94102-4507" "94102-4507" "94102-4507"
#  [781] "94102-4507" "94102-4507" "94102-4507" "94102-4507" "94102-4507"
#  [786] "94102-4507" "94102-4507" "94102-4507" "94102-4507" "94102-4507"
#  [791] "94102-4507" "94102-4507" "94102-4507" "94102-4507" "94102-4507"
#  [796] "99201-0916" "99201-0916" "99201-0916" "99201-0916" "99201-0916"
#  [801] "99201-0916" "99201-0916" "99201-0916" "63105-0358" "94607-4892"
#  [806] "98368-0958" "98368-0958" "98368-0958" "98368-0958" "98368-0958"
#  [811] "98368-0958" "98368-0958" "98368-0958" "98368-0958" "98368-0958"
#  [816] "98368-0958" "20005-4943" "20005-4943" "20005-4943" "20005-4943"
#  [821] "20005-4943" "20005-4943" "12207-2211" "12207-2211" "12207-2211"
#  [826] "12207-2211" "12207-2211" "12207-2211" "12207-2211" "12207-2211"
#  [831] "12207-2211" "12207-2211" "12207-2211" "12207-2211" "10019-5515"
#  [836] "10019-5515" "10019-5515" "10019-5515" "10019-5515" "10019-5515"
#  [841] "10019-5515" "10019-5515" "10019-5515" "94704-1246" "94704-1246"
#  [846] "94704-1246" "94704-1246" "94704-1246" "94704-1246" "94704-1246"
#  [851] "94704-1246" "94704-1246" "94704-1246" "02143-3538" "02143-3538"
#  [856] "02143-3538" "02143-3538" "02143-3538" "10023-6582" "10023-6582"
#  [861] "10023-6582" "10023-6582" "10023-6582" "10023-6582" "10023-6582"
#  [866] "10023-6582" "10023-6582" "10023-6582" "10023-6582" "10023-6582"
#  [871] "10023-6582" "10023-6582" "45202-2518" "45202-2518" "45202-2518"
#  [876] "45202-2518" "10003-8991" "10003-8991" "10003-8991" "10003-8991"
#  [881] "10003-8991" "10003-8991" "10003-8991" "10003-8991" "10003-8991"
#  [886] "10003-8991" "10003-8991" "10003-8991" "10003-8991" "10014-1791"
#  [891] "10014-1791" "10023-6053" "10023-6053" "10023-6053" "10023-6053"
#  [896] "10023-6053" "10023-6053" "10023-6053" "20141-2300" "20141-2300"
#  [901] "96814-1495" "96814-1495" "00902-4184" "00902-4184" "00902-4184"
#  [906] "00902-4184" "00902-4184" "00902-4184" "00902-4184" "63108-1160"
#  [911] "11372-2705" "11372-2705" "55102-1497" "55102-1497" "55102-1497"
#  [916] "55102-1497" "55102-1497" "55102-1497" "55102-1497" "55102-1497"
#  [921] "55102-1497" "55102-1497" "55102-1497" "94102-3916" "94102-3916"
#  [926] "94102-3916" "94102-3916" "94102-3916" "94102-3916" "94102-3916"
#  [931] "13224-1839" "13224-1839" "13224-1839" "13224-1839" "13224-1839"
#  [936] "13224-1839" "13224-1839" "24061-0001" "24061-0001" "24061-0001"
#  [941] "24061-0001" "24061-0001" "24061-0001" "24061-0001" "24061-0001"
#  [946] "24061-0001" "24061-0001" "24061-0001" "24061-0001" "24061-0001"
#  [951] "10107-1218" "10107-1218" "10107-1218" "10107-1218" "10107-1218"
#  [956] "10107-1218" "10107-1218" "10107-1218" "79101-3408" "10023-7905"
#  [961] "10023-7905" "10023-7905" "10023-7905" "10023-7905" "10023-7905"
#  [966] "10023-7905" "10023-7905" "10023-7905" "10023-7905" "10023-7905"
#  [971] "10023-7905" "10023-7905" "10018-0286" "10018-0286" "10018-0286"
#  [976] "10018-0286" "10018-0286" "10018-0286" "10018-0286" "72217-7328"
#  [981] "72217-7328" "72217-7328" "72217-7328" "72217-7328" "72217-7328"
#  [986] "72217-7328" "72217-7328" "78701-1912" "78701-1912" "78701-1912"
#  [991] "21201-5556" "21201-5556" "21201-5556" "21201-5556" "21201-5556"
#  [996] "21201-5556" "21201-5556" "21201-5556" "21201-5556" "21201-5556"

# %%
NEA$CoZip <- get_padded_zip(NEA$CoZip)

# %%
help("create_full_address")

# %% [markdown]
# **Example:**
#
# NEA$full_address <- create_full_address(NEA, c("CoAddress1", "CoAddress2",
# "CoCity", "CoState", "CoZip"))

# %%
NEA$address <- create_full_address(NEA, c("CoAddress1", "CoAddress2", "CoCity", "CoState", "CoZip"))

# %% [markdown]
# Run the "get_geocode_data" command with the previously created "NEA$Address" object as the command's input. This will geocode each address in the "NEA" object and assign the (Lat, Lon) combination to the "coords" object.

# %%
coords <- get_geocode_data(NEA$address)

# %% [markdown]
# Assign the latitude values held within the "coords" object to the "NEA" object in its own field called "NEA$Latitude". This creates a new column with only Latitude values.

# %%
NEA$Latitude <- coords$lat

# %% [markdown]
# Assign the longitude values within the "coords" object to the "NEA" object in its own field called "NEA$Longitude". This creates a new column with only Longitude values.

# %%
NEA$Longitude <- coords$lon

# %% [markdown]
# You can view these newly added columns briefly by using the "head(NEA)" command. THe Latitude and Longitude columns are all the way to the right in this view.

# %%
head(NEA)
# Out:
#   X ApplicationNumber Discipline CoName
# 1 1 10-922191         Music      Chorus America Association
# 2 2 11-932113         Music      Chorus America Association
# 3 3 13-948528         Music      Chorus America Association
# 4 4 17-980612         Music      Chorus America Association
# 5 5 17-980082         Research   Chorus America Association
# 6 6 16-969075         Music      Chorus America Association
#   CoAddress1           CoAddress2 CoCity     CoState CoZip      TOTAL_AUDIENCE
# 1 1156 15th Street, NW Suite 310  Washington DC      20005-1747  0
# 2 1156 15th Street, NW Suite 310  Washington DC      20005-1747 NA
# 3 1156 15th Street, NW Suite 310  Washington DC      20005-1747  0
# 4 1156 15th Street, NW Suite 310  Washington DC      20005-1747  0
# 5 1156 15th Street, NW Suite 310  Washington DC      20005-1747  0
# 6 1156 15th Street, NW Suite 310  Washington DC      20005-1747  0
#   ⋯ Committed FY   FdrFlag Disposition Individual CT_NAMELSAD      CT_GEOID
# 1 ⋯ 100000    2011 A       Awarded     NA         Census Tract 101 11001010100
# 2 ⋯      0    2012         Rejected    NA         Census Tract 101 11001010100
# 3 ⋯  95000    2014 A       Awarded     NA         Census Tract 101 11001010100
# 4 ⋯     NA    2018         Pending     NA         Census Tract 101 11001010100
# 5 ⋯  20000    2017         Awarded     NA         Census Tract 101 11001010100
# 6 ⋯  90000    2017         Awarded     NA         Census Tract 101 11001010100
#   address                                                     Latitude
# 1 1156 15th Street, NW, Suite 310, Washington, DC, 20005-1747 38.90483
# 2 1156 15th Street, NW, Suite 310, Washington, DC, 20005-1747 38.90483
# 3 1156 15th Street, NW, Suite 310, Washington, DC, 20005-1747 38.90483
# 4 1156 15th Street, NW, Suite 310, Washington, DC, 20005-1747 38.90483
# 5 1156 15th Street, NW, Suite 310, Washington, DC, 20005-1747 38.90483
# 6 1156 15th Street, NW, Suite 310, Washington, DC, 20005-1747 38.90483
#   Longitude
# 1 -77.03465
# 2 -77.03465
# 3 -77.03465
# 4 -77.03465
# 5 -77.03465
# 6 -77.03465

# %% [markdown]
# ## Advanced commands

# %% [markdown]
# This command assigns MSA data to the object "msa" using the command "get_msa_data". This command is provided in the "neaR" package.

# %%
help("get_msa_data")

# %% [markdown]
# **Usage:** get_msa_data(Latitude, Longitude, year = 2016)

# %%
msa <- get_msa_data(NEA$Latitude, NEA$Longitude)

# %% [markdown]
# Use the following command to view the first six rows of the "msa" object and the column names.

# %%
head(msa)
# Out:
#   cbsa_GEOID cbsa_NAMELSAD                                           cbsa_LSAD
# 1 47900      Washington-Arlington-Alexandria, DC-VA-MD-WV Metro Area M1
# 2 47900      Washington-Arlington-Alexandria, DC-VA-MD-WV Metro Area M1
# 3 47900      Washington-Arlington-Alexandria, DC-VA-MD-WV Metro Area M1
# 4 47900      Washington-Arlington-Alexandria, DC-VA-MD-WV Metro Area M1
# 5 47900      Washington-Arlington-Alexandria, DC-VA-MD-WV Metro Area M1
# 6 47900      Washington-Arlington-Alexandria, DC-VA-MD-WV Metro Area M1
#   source
# 1 MSA
# 2 MSA
# 3 MSA
# 4 MSA
# 5 MSA
# 6 MSA

# %% [markdown]
# Create a new column in the "NEA" object. It will appear all the way to the right if you run the "View(NEA)" command.

# %%
NEA$poverty_rate <- NA

# %% [markdown]
# ***NOTE:*** If your object does not already have a "CT_GEOID" column, you need to assign a NEA$CT_GEOID column and run the "get_ct_data" command in the "neaR" package.

# %%
NEA$poverty_rate <- append_poverty_data(NEA$CT_GEOID, NEA$poverty_rate)

# %% [markdown]
# Save the "NEA" object to a CSV using the following command. The resulting file will be saved in your working directoy set at the beginning of the tutorial.

# %%
write.csv(NEA, "workshop_sample.csv")
